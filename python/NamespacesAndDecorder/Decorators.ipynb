# %% [markdown]
# ### Decorators
#
# A decorator in python is a function that receives another function as input and adds some functionality(decoration) to and it and returns it.
#
# This can happen only because python functions are 1st class citizens.
#
# There are 2 types of decorators available in python
# - `Built in decorators` like `@staticmethod`, `@classmethod`, `@abstractmethod` and `@property` etc
# - `User defined decorators` that we programmers can create according to our needs

# %%
# Python are 1st class function

def modify(func,num):    # Decoraters
  return func(num)

def square(num):      # Input
  return num**2

modify(square,2)
# Out:
# 4

# %%
# simple example:

def my_decorator(func):
    def wrapper():
        print('*************************')
        func()
        print('*************************')
    return wrapper

def hello():
    print('hello')

def display():
    print('Hello Ammar')

a = my_decorator(hello)
a()

b = my_decorator(display)
b()
# Out:
# *************************
# hello
# *************************
# *************************
# Hello Ammar
# *************************

# %%
def outer():
    a = 5
    def inner():
        print(a)
    return inner

b = outer()
b()
# Out:
# 5

# %%
# Better Syntax:

def my_decorator(func):
    def wrapper():
        print('*************************')
        func()
        print('*************************')
    return wrapper

@my_decorator
def hello():
    print('hello')

hello()
# Out:
# *************************
# hello
# *************************

# %%
# anythings meaningful decorators

import time

def Timer(func):
    def wrapper(*args):
        start_time = time.time()
        func(*args)
        print("Time taken by ",func.__name__,time.time() - start_time,'secs')
    return wrapper

@Timer
def hello():
    print('Hello World!')
    time.sleep(2)

@Timer
def square(num):
    print(num**2)
    time.sleep(1)

@Timer
def power(a,b):
    
    print(a**b)
    


hello()
square(4)
power(2,3)
# Out:
# Hello World!
# Time taken by  hello 2.0000460147857666 secs
# 16
# Time taken by  square 3.004244327545166 secs
# 8
# Time taken by  power 0.000102996826171875 secs

# %%
# A big problem

def sanity_check(data_type):
    def outer_wrapper(func):
        def inner_wrapper(*args):
            if type(args[0]) == data_type:
                func(*args)
            else:
                raise TypeError('Ye Datatype nai chalega')
        return inner_wrapper
    return outer_wrapper

@sanity_check(int)
def square(num):
    print(num**2)

@sanity_check(str)
def greet(name):
    print('hello ', name)
try:
   greet('Ammar')
   square(5)
except Exception as e:
    print(e)
# Out:
# hello  Ammar
# 25
